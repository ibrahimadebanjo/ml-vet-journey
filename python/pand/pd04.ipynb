# %%
import pandas as pd
bios = pd.read_csv("C:\\Users\\IBRAHIM\\Documents\\ml-vet-journey\\python\\pand\\bios.csv")
bios.head()
bios.tail()
bios.info()
bios[(bios["height_cm"] > 215)]
bios[(bios["height_cm"] > 215) & (bios['born_country'] == "USA")]
bios.plot.bar
bios.query('born_country == "USA" and born_city == "Seattle"')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99529 entries, 0 to 99528
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   athlete_id    99529 non-null  int64
#  1   name          99529 non-null  object
#  2   born_date     97756 non-null  object
#  3   born_city     73132 non-null  object
#  4   born_region   73132 non-null  object
#  5   born_country  73132 non-null  object
#  6   NOC           99528 non-null  object
#  7   height_cm     69275 non-null  float64
#  8   weight_kg     66506 non-null  float64
#  9   died_date     33447 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.6+ MB
#        athlete_id             name   born_date born_city born_region  \
# 11030       11088    David Halpern  1955-08-18   Seattle  Washington
# 12800       12870      Todd Trewin  1958-04-20   Seattle  Washington
# 15476       15583   Scott McKinley  1968-10-15   Seattle  Washington
# ...
