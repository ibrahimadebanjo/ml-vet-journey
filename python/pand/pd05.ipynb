# %%
import pandas as pd
coffee = pd.read_csv("C:\\Users\\IBRAHIM\\Documents\\ml-vet-journey\\python\\pand\\coffee.csv")
# Adding and removing columns
# Adding columns
coffee['price'] = 4.99
coffee.head()
coffee.drop(0)
coffee.drop(7)
coffee.drop(columns = ['price'])
coffee
# Shifting forward
coffee['yesterday_revenue'] = coffee['Units Sold'].shift(1)
coffee['yesterday_revenue'] = coffee['Units Sold'].shift(2)
# shifting backwards
coffee['yesterday_revenue'] = coffee['Units Sold'].shift(-1)
coffee['yesterday_revenue'] = coffee['Units Sold'].shift(-2)
coffee['pct_change'] = coffee['Units Sold'] / coffee['yesterday_revenue'] * 100
coffee.cumsum()
coffee['cummulative_revenue'] = coffee['yesterday_revenue'].cumsum()
coffee
# Out:
#           Day Coffee Type  Units Sold  price  yesterday_revenue  pct_change  \
# 0      Monday    Espresso          25   4.99               30.0   83.333333
# 1      Monday       Latte          15   4.99               20.0   75.000000
# 2     Tuesday    Espresso          30   4.99               35.0   85.714286
# 3     Tuesday       Latte          20   4.99               25.0   80.000000
# 4   Wednesday    Espresso          35   4.99               40.0   87.500000
# 5   Wednesday       Latte          25   4.99               30.0   83.333333
# 6    Thursday    Espresso          40   4.99               45.0   88.888889
# 7    Thursday       Latte          30   4.99               35.0   85.714286
# 8      Friday    Espresso          45   4.99               45.0  100.000000
# 9      Friday       Latte          35   4.99               35.0  100.000000
# 10   Saturday    Espresso          45   4.99               45.0  100.000000
# ...
