# %%
import pandas as pd
bios = pd.read_csv("C:\\Users\\IBRAHIM\\Documents\\ml-vet-journey\\python\\pand\\bios.csv")
bios_new = bios.copy()
bios_new.query('NOC == "FRANCE"')
bios_new.head()
bios_new[["name","born_date"]]
# Aggregating Data
bios.head()
bios.value_counts()
bios[bios['born_country'] == 'USA'] ['born_region'].value_counts() 
bios[bios['born_country'] == 'USA'] ['born_region'].value_counts().tail(10)
# Tail() display last few rows of a dataframe by default it shows 5 rows
# bios.groupby(bios['born_date'].dt.year)['name'].count()
bios['highest_rank'] = bios['height_cm'].rank()
bios
# Out:
#        athlete_id                   name   born_date           born_city  \
# 0               1  Jean-François Blanchy  1886-12-12            Bordeaux
# 1               2         Arnaud Boetsch  1969-04-01              Meulan
# 2               3           Jean Borotra  1898-08-13            Biarritz
# 3               4        Jacques Brugnon  1895-05-11         Paris VIIIe
# 4               5           Albert Canet  1878-04-17          Wandsworth
# ...           ...                    ...         ...                 ...
# 99524      100323           Holger Höhne  1970-05-06              Füssen
# 99525      100324              Andy Kapp  1967-12-08           Sonthofen
# 99526      100325               Uli Kapp  1971-04-14              Füssen
# 99527      100326       Michael Schäffer  1968-04-28  Neunburg vorm Wald
# 99528      100327          Hirofumi Kudo          19                 NaN
#
#                 born_region born_country                   NOC  height_cm  \
# ...
